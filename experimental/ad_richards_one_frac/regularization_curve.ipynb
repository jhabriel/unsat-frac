# %%
import porepy as pp
import numpy as np
import scipy.sparse as sps
import matplotlib.pyplot as plt

# %%
x = np.linspace(-0.3, 0.3, 100)
y = pp.ad.heaviside_smooth(x)

fig, ax = plt.subplots()
ax.plot(x, y, marker='.')
ax.set(xlabel='x', ylabel='y', title="Smooth Heaviside function")
plt.show()
